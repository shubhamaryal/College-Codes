# %% [markdown]
# # Learning Python Basics

# %% [markdown]
# ## Variables

# %%
name = 'Ram'

# %%
type(name)
# Out:
# str

# %%
marks = [88, 92, 75, 80]

# %%
type(marks)
# Out:
# list

# %%
marks_tuple = (88, 55, 33)

# %%
type(marks_tuple)
# Out:
# tuple

# %%
marks.append(55)

# %%
print(marks)
# Out:
# [88, 92, 75, 80, 55]

# %%
marks_tuple.append(55)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 marks_tuple.append(55)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
from calculate_grade import calculate_grade

a = calculate_grade(95)
print(a)
# Out:
# A
