# %%
import os
import sqlite3
import json
import shutil
import pandas as pd

# CHANGE THESE PATHS FOR YOUR MACHINE
BASE_PATH = './OSV240812/'           # Parent directory containing the folder
FOLDER_NAME = '202406081229'         # Single folder to process

TRACK_FILE = os.path.join(BASE_PATH, FOLDER_NAME, 'track.txt')
DB_PATH    = os.path.join(BASE_PATH, 'track_data.db')
JS_PATH    = os.path.join(BASE_PATH, 'roads.js')

# Template location
# In python file you can use __file__ as shown below
# TEMPLATE_PATH = os.path.join(os.path.dirname(__file__), 'mapview.template')
TEMPLATE_PATH = os.path.join(os.getcwd(), 'mapview.template')
HTML_OUTPUT   = os.path.join(BASE_PATH, 'view.html')

print("Configuration loaded:")
print(f"Track file: {TRACK_FILE}")
print(f"Database:   {DB_PATH}")
print(f"Template:   {TEMPLATE_PATH}")
# Out:
# Configuration loaded:
# Track file: ./OSV240812/202406081229/track.txt
# Database:   ./OSV240812/track_data.db
# Template:   /Users/shubham/Developer/LearnCode/_College/5th sem/Python-Class/3rd_class/mapview.template

# %%
def
