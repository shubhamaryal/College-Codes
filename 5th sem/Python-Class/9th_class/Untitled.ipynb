# %%
import statsmodels.api as sm

X = df['Height']
y = df['Weight']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 import statsmodels.api as sm
# ----> 3 X = df['Height']
#       4 y = df['Weight']
#       6 X = sm.add_constant(X)
#
# NameError: name 'df' is not defined

# %%
df['Time'] = pd.to_datetime(df['Time'])      # ads
df['Date'] = pd.to_datetime(df['Date'])      # ads_hour
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df['Time'] = pd.to_datetime(df['Time'])      # ads
#       2 df['Date'] = pd.to_datetime(df['Date'])
#
# NameError: name 'df' is not defined

# %%
df['t'] = range(len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df['t'] = range(len(df))
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
plt.plot(df['Time'], df['Ads'])
plt.xlabel('Time')
plt.ylabel('Number of Ads')
plt.title('Ads over Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.plot(df['Time'], df['Ads'])
#       2 plt.xlabel('Time')
#       3 plt.ylabel('Number of Ads')
#
# NameError: name 'plt' is not defined

# %%
import statsmodels.api as sm

X = sm.add_constant(df['t'])   # intercept + trend
y = df['Ads']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 import statsmodels.api as sm
# ----> 3 X = sm.add_constant(df['t'])   # intercept + trend
#       4 y = df['Ads']
#       6 model = sm.OLS(y, X).fit()
#
# NameError: name 'df' is not defined

# %%
df['t'] = range(len(df))
df['sin_t'] = np.sin(2 * np.pi * df['t'] / 24)
df['cos_t'] = np.cos(2 * np.pi * df['t'] / 24)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df['t'] = range(len(df))
#       2 df['sin_t'] = np.sin(2 * np.pi * df['t'] / 24)
#       3 df['cos_t'] = np.cos(2 * np.pi * df['t'] / 24)
#
# NameError: name 'df' is not defined
