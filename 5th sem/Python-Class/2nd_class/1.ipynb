# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('enct325.db')

query = "SELECT * FROM users"
result = pd.read_sql(query,conn)
print(result)

conn.close()
# Out:
#     roll_number              full_name  \
# 0             1         Aarati Ghimire
# 1             3       AaryamanMaharjan
# 2             4        Aaryan Adhikari
# 3             6        Aashutosh Karna
# 4             7           Aayush Dangi
# 5            13            Anubhav Jha
# 6            16          Arustha Thapa
# 7            18         Ayush Rauniyar
# 8            20           Bishal Joshi
# 9            21           Brisha Rimal
# 10           23     Aayushma Chaudhari
# 11           24     Dipak Kumar Mandal
# 12           31           manish hathi
# 13           32   Mukesh Kumar Mahato
# 14           42     Preetisha Shrestha
# 15           51         SANDESH KHADKA
# 16           54          Saurav Kunwar
# 17           55           Shine Panday
# 18           58          Shubham Aryal
# 19           59         Shubrat Dhital
# 20           60  siddhanta mani pandey
# 21           65           Sulav Dangol
# 22           66       Supreme Adhikari
# ...

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result.to_excel('student.xlsx')

# %%
import pandas as pd

df = pd.read_csv('Hhld01_OwnershipOfHouse.csv')

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4       prov       dist       gapa
#
#   Table 01: Number of households by type of ownership of housing unit, NPHC 2021  \
# 0                                                NaN
# 1                                               Area
# 2                                                NaN
# 3                                                NaN
# 4                                           provname
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN                 NaN        NaN
# 1        NaN        NaN      Total  Type of ownership         NaN
# 2        NaN        NaN        NaN               Owned     Rented
# 3        NaN        NaN        NaN                 NaN        NaN
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 838          7         77          5
# 839          7         77          6
# 840          7         77          7
# 841          7         77          8
# 842          7         77          9
#
#     Table 01: Number of households by type of ownership of housing unit, NPHC 2021  \
# 838                                       Sudurpaschim
# 839                                       Sudurpaschim
# 840                                       Sudurpaschim
# 841                                       Sudurpaschim
# 842                                       Sudurpaschim
#
#      Unnamed: 4                     Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 838  Kanchanpur  Dodhara Chandani Municipality       9610       9465
# 839  Kanchanpur            Laljhadi Gaunpalika       4745       4724
# 840  Kanchanpur          Punarbas Municipality      13626      13244
# 841  Kanchanpur           Belouri Municipality      11151      10813
# ...

# %%
max_hh_index = df['a_Own'].idxmax()

# Get the full row
max_hh_row = df.loc[max_hh_index]

print(max_hh_row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a_Own'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 max_hh_index = df['a_Own'].idxmax()
#       3 # Get the full row
# ...

# %%
df_gapa = df.loc[df['gapa'] > 0].copy()
